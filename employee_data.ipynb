# %%
import pandas as pd

# %%
data= r"C:\Users\Lenovo\Downloads\Employee Sample Data - A.xlsx"
df= pd.read_excel(data)

# %% [markdown]
# task 1

# %%
df.head()
# Out:
#      EEID        Full Name                 Job Title Department  \
# 0  E02387      Emily Davis                Sr. Manger         IT
# 1  E04105    Theodore Dinh       Technical Architect         IT
# 2  E02572     Luna Sanders                  Director    Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager         IT
# 4  E01639        Austin Vo               Sr. Analyst    Finance
#
#             Business Unit  Gender  Ethnicity   Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female      Black  55.0 2016-04-08       141604.0
# 1           Manufacturing    Male      Asian  59.0 1997-11-29        99975.0
# 2     Speciality Products  Female  Caucasian  50.0 2006-10-26       163099.0
# 3           Manufacturing  Female  Caucasian  26.0 2019-09-27        84913.0
# 4           Manufacturing    Male      Asian  55.0 1995-11-20        95409.0
#
#    Bonus %        Country       City  Exit Date
# 0     0.15  United States    Seattle 2021-10-16
# ...

# %%
df
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity   Age  Hire Date  \
# 0    Research & Development  Female      Black  55.0 2016-04-08
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   EEID           1000 non-null   object
#  1   Full Name      998 non-null    object
#  2   Job Title      999 non-null    object
#  3   Department     998 non-null    object
#  4   Business Unit  1000 non-null   object
#  5   Gender         999 non-null    object
#  6   Ethnicity      993 non-null    object
#  7   Age            994 non-null    float64
#  8   Hire Date      993 non-null    datetime64[ns]
#  9   Annual Salary  989 non-null    float64
#  10  Bonus %        992 non-null    float64
#  11  Country        998 non-null    object
#  12  City           998 non-null    object
#  13  Exit Date      85 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), float64(3), object(9)
# memory usage: 109.5+ KB

# %%
df.isna().sum()
# Out:
# EEID               0
# Full Name          2
# Job Title          1
# Department         2
# Business Unit      0
# Gender             1
# Ethnicity          7
# Age                6
# Hire Date          7
# Annual Salary     11
# Bonus %            8
# Country            2
# City               2
# Exit Date        915
# dtype: int64

# %% [markdown]
# task 2

# %%
df.drop('Exit Date', axis=1, inplace=True)

# %%
df.dropna(inplace= True)

# %%
df.isna().sum()
# Out:
# EEID             0
# Full Name        0
# Job Title        0
# Department       0
# Business Unit    0
# Gender           0
# Ethnicity        0
# Age              0
# Hire Date        0
# Annual Salary    0
# Bonus %          0
# Country          0
# City             0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 980, dtype: bool

# %%
df
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity   Age  Hire Date  \
# 0    Research & Development  Female      Black  55.0 2016-04-08
# ...

# %% [markdown]
# task 3

# %%
df.iloc[:5]
# Out:
#      EEID        Full Name                 Job Title Department  \
# 0  E02387      Emily Davis                Sr. Manger         IT
# 1  E04105    Theodore Dinh       Technical Architect         IT
# 2  E02572     Luna Sanders                  Director    Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager         IT
# 4  E01639        Austin Vo               Sr. Analyst    Finance
#
#             Business Unit  Gender  Ethnicity   Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female      Black  55.0 2016-04-08       141604.0
# 1           Manufacturing    Male      Asian  59.0 1997-11-29        99975.0
# 2     Speciality Products  Female  Caucasian  50.0 2006-10-26       163099.0
# 3           Manufacturing  Female  Caucasian  26.0 2019-09-27        84913.0
# 4           Manufacturing    Male      Asian  55.0 1995-11-20        95409.0
#
#    Bonus %        Country       City
# 0     0.15  United States    Seattle
# 1     0.00          China  Chongqing
# ...

# %%
df.loc[df.index[:5], "Age"] += 1
df.loc[df.index[:5], "Annual Salary"] +=1000

# %% [markdown]
# task 4

# %%
max_row = df.loc[df["Annual Salary"].idxmax()]
print(max_row)
# Out:
# EEID                          E04354
# Full Name               Raelynn Rios
# Job Title             Vice President
# Department                     Sales
# Business Unit          Manufacturing
# Gender                        Female
# Ethnicity                     Latino
# Age                             43.0
# Hire Date        2016-08-21 00:00:00
# Annual Salary               258498.0
# Bonus %                         0.35
# Country                United States
# City                        Columbus
# Name: 989, dtype: object

# %% [markdown]
# task 5

# %%
dept_summary = df.groupby("Department")[["Age","Annual Salary"]].mean()
dept_summary
# Out:
#                        Age  Annual Salary
# Department
# Accounting       43.656250  123146.947917
# Engineering      46.026144  108750.379085
# Finance          45.051282  123464.564103
# Human Resources  44.327869  118256.926230
# IT               44.290598   97664.858974
# Marketing        43.042017  129451.563025
# Sales            43.604317  111225.338129

# %% [markdown]
# task 6

# %%
dept_eth_summary = df.groupby(["Department","Ethnicity"]).agg({
    "Age": ["max","min"],
    "Annual Salary": "median"
})
dept_eth_summary
# Out:
#                             Age       Annual Salary
#                             max   min        median
# Department      Ethnicity
# Accounting      Asian      64.0  25.0      114893.0
#                 Black      51.0  30.0       91853.0
#                 Caucasian  62.0  26.0      121159.5
#                 Latino     62.0  26.0       92317.0
# Engineering     Asian      65.0  25.0       91230.0
#                 Black      56.0  27.0       74412.0
#                 Caucasian  64.0  25.0       90658.0
#                 Latino     64.0  27.0       96818.0
# Finance         Asian      64.0  25.0      124928.0
#                 Black      65.0  25.0      131652.0
#                 Caucasian  64.0  25.0      102847.0
#                 Latino     65.0  25.0      124553.0
# Human Resources Asian      64.0  25.0      125936.0
#                 Black      55.0  25.0      142318.0
#                 Caucasian  64.0  26.0      104162.0
#                 Latino     65.0  29.0      101985.0
# ...

# %%
output_path = "Employee_Analysis_Output2.xlsx"

with pd.ExcelWriter(output_path, engine="openpyxl") as writer:
    df.to_excel(writer, sheet_name="Cleaned_Data", index=False)
    dept_summary.to_excel(writer, sheet_name="Dept_Averages")
    dept_eth_summary.to_excel(writer, sheet_name="Dept_Ethnicity_Stats")

print("Saved to:", output_path)
# Out:
# Saved to: Employee_Analysis_Output2.xlsx

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Lenovo

# %% [markdown]
# matplot

# %%
import matplotlib.pyplot as plt

# %%
df
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity   Age  Hire Date  \
# 0    Research & Development  Female      Black  56.0 2016-04-08
# ...

# %%
plt.figure(figsize=(8,5))

sns.countplot(x="Department", data=df)

plt.title("Number of employees in each department")
plt.xticks(rotation=45)
plt.savefig("department_employees_number.png")
plt.show()

# %%
dept_salary = df.groupby("Department")["Annual Salary"].mean().reset_index()

plt.figure(figsize=(8,5))

sns.barplot(x="Department", y="Annual Salary", data=dept_salary)

plt.title("Average salary in each department")
plt.xticks(rotation=45)
plt.savefig("employees_salary.png")
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["Age"], bins=20)

plt.title("Age Distribution")
plt.savefig("employees_age.png")
plt.show()

# %%
plt.figure(figsize=(6,6))

df["Gender"].value_counts().plot.pie(autopct="%1.1f%%")

plt.title("Gender Distribution")
plt.savefig("gender.png")

plt.show()

# %%
import seaborn as sns

# %%
plt.figure(figsize=(8,5))

sns.boxplot(x="Department", y="Annual Salary", data=df)

plt.xticks(rotation=45)
plt.title("Salary Distribution by Department")
plt.savefig("Salary Distribution by Department.png")

plt.show()

# %%
plt.figure(figsize=(6,4))

corr = df[["Age","Annual Salary","Bonus %"]].corr()

sns.heatmap(corr, annot=True, cmap="coolwarm")

plt.title("Correlation Heatmap")
plt.savefig("Correlation Heatmap.png")

plt.show()
